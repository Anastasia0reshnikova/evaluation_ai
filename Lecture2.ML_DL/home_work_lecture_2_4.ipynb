# %% [raw]
# Задание 4.
#
# Ссылка на репозиторий лекции: https://github.com/meshkovQA/Evaluation_AI_course/tree/44b6b8161ae26b1e1dd564ffe0fff4e087955c00/Lecture2.ML_DL
#
# Выполните глубокое обучение на датасете MNIST, используя подготовленный пример из файла classification.py и новые архитектуры моделей (VerySimpleCNN и SimpleCNN).
#
# Результатом выполнения данного задания является текстовый отчет в любом формате (txt, docs, pdf, другие), в котором отображены результаты оценки, полученные данные и графики, а также ваши выводы по полученным результатам.

# %%
# Импорт необходимых библиотек
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Настройка стиля графиков
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
